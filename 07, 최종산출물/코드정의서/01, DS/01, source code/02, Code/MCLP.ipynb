# %% [markdown]
# # **데이터 전처리**

# %% [markdown]
# ## **서울시 인구 데이터 전처리**

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.19.5)

# %%
import geopandas as gpd
import pandas as pd

# %%
df_pop=gpd.read_file('df_pop.shp', encoding = 'utf-8')

# %%
# VAL: 격자 내 인구수

df_pop
# Out:
#             gid  ...                                           geometry
# 0      다사579454  ...  POLYGON ((957900.000 1945400.000, 957900.000 1...
# 1      다사613448  ...  POLYGON ((961300.000 1944800.000, 961300.000 1...
# 2      다사585452  ...  POLYGON ((958500.000 1945200.000, 958500.000 1...
# 3      다사583456  ...  POLYGON ((958300.000 1945600.000, 958300.000 1...
# 4      다사585468  ...  POLYGON ((958500.000 1946800.000, 958500.000 1...
# ...         ...  ...                                                ...
# 64671  다사656567  ...  POLYGON ((965600.000 1956700.000, 965600.000 1...
# 64672  다사636570  ...  POLYGON ((963600.000 1957000.000, 963600.000 1...
# 64673  다사628533  ...  POLYGON ((962800.000 1953300.000, 962800.000 1...
# 64674  다사661574  ...  POLYGON ((966100.000 1957400.000, 966100.000 1...
# 64675  다사622562  ...  POLYGON ((962200.000 1956200.000, 962200.000 1...
#
# [64676 rows x 4 columns]

# %%
df_pop = df_pop.to_crs(epsg=4329)
df_pop.head()
# Out:
#         gid     lbl    val                                           geometry
# 0  다사579454  143.00  143.0  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1  다사613448  235.00  235.0  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2  다사585452   19.00   19.0  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3  다사583456  459.00  459.0  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4  다사585468    9.00    9.0  POLYGON ((127.03037 37.51956, 127.03036 37.520...

# %%
#Pydeck 사용을 위한 함수 정의
import geopandas as gpd 
import shapely # Shapely 형태의 데이터를 받아 내부 좌표들을 List안에 반환합니다. 
def line_string_to_coordinates(line_string): 
    if isinstance(line_string, shapely.geometry.linestring.LineString): 
        lon, lat = line_string.xy 
        return [[x, y] for x, y in zip(lon, lat)] 
    elif isinstance(line_string, shapely.geometry.multilinestring.MultiLineString): 
        ret = [] 
        for i in range(len(line_string)): 
            lon, lat = line_string[i].xy 
            for x, y in zip(lon, lat): 
                ret.append([x, y])
        return ret 

# def multipolygon_to_coordinates(x): 
#     lon, lat = x[0].exterior.xy 
    return [[x, y] for x, y in zip(lon, lat)] 

def polygon_to_coordinates(x): 
    lon, lat = x.exterior.xy 
    return [[x, y] for x, y in zip(lon, lat)]

# %%
# val 열 na 제거
df_pop['val'] = df_pop['val'].fillna(0)

# 인구 수 정규화
df_pop['nor_pop'] = df_pop['val'] / df_pop['val'].max()

# geometry를 coordinate 형태로 적용
df_pop['coordinates'] = df_pop['geometry'].apply(polygon_to_coordinates)

# %%
df_pop['geometry']
# Out:
# 0        POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1        POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2        POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3        POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4        POLYGON ((127.03037 37.51956, 127.03036 37.520...
#                                ...
# 64671    POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672    POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673    POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674    POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675    POLYGON ((127.07175 37.60444, 127.07175 37.605...
# Name: geometry, Length: 64676, dtype: geometry

# %%
# 100X100 grid에서 central point 찾기
df_pop_list = []
df_pop_list2 = []
for i in df_pop['geometry']:
    cent = [[i.centroid.coords[0][0],i.centroid.coords[0][1]]]
    df_pop_list.append(cent)
    df_pop_list2.append(i.centroid)
df_pop['coord_cent'] = 0
df_pop['geo_cent'] = 0
df_pop['coord_cent']= pd.DataFrame(df_pop_list) # pydeck을 위한 coordinate type
df_pop['geo_cent'] = df_pop_list2 # geopandas를 위한 geometry type

# %%
df_pop
# Out:
#             gid  ...                                     geo_cent
# 0      다사579454  ...  POINT (127.0242225272549 37.50736754818467)
# 1      다사613448  ...  POINT (127.0627225223319 37.50210819142225)
# 2      다사585452  ...  POINT (127.0310223340312 37.50559202546111)
# 3      다사583456  ...  POINT (127.0287368798365 37.50918835992229)
# 4      다사585468  ...  POINT (127.0309320874575 37.52001337639122)
# ...         ...  ...                                          ...
# 64671  다사656567  ...  POINT (127.1108132479357 37.60953739424148)
# 64672  다사636570  ...  POINT (127.0881387855741 37.61216447014212)
# 64673  다사628533  ...   POINT (127.079262473061 37.57878336317809)
# 64674  다사661574  ...   POINT (127.116445745636 37.61586524446711)
# 64675  다사622562  ...  POINT (127.0723178683743 37.60489744470913)
#
# [64676 rows x 8 columns]

# %%
# 쉬운 분석을 위한 임의의 grid id 부여
df_pop['grid_id']=0
idx = []
for i in range(len(df_pop)):
    idx.append(str(i).zfill(5))
df_pop['grid_id'] = pd.DataFrame(idx)

# 인구 현황이 가장 높은 위치
df_pop.iloc[df_pop["val"].sort_values(ascending=False).index].reindex().head()
# Out:
#             gid       lbl  ...                                     geo_cent grid_id
# 44329  다사567549  13178.00  ...   POINT (127.0100853556977 37.5929380519025)   44329
# 45999  다사668423   7196.00  ...  POINT (127.1250596271927 37.47978842300248)   45999
# 60     다사605432   4215.00  ...  POINT (127.0537575657725 37.48765290058997)   00060
# 37003  다사583435   3627.00  ...  POINT (127.0288558230769 37.49026030074194)   37003
# 61656  다사526506   3594.00  ...  POINT (126.9639222543317 37.55397956569163)   61656
#
# [5 rows x 9 columns]

# %% [markdown]
# ## **자동차등록 데이터 전처리**

# %%
df_car = pd.read_excel('21년 1월 기준 서울시 자동차 등록현황.xlsx')

# %%
df_car
# Out:
#          사용본거지법정동명  동별 총 대수     휘발유  ...  하이브리드\n(CNG+전기)    수소  기타연료
# 0    서울특별시 종로구 청운동      800   220.0  ...              NaN   NaN   2.0
# 1    서울특별시 종로구 신교동      383    87.0  ...              NaN   NaN   NaN
# 2    서울특별시 종로구 궁정동       47    10.0  ...              NaN   NaN   NaN
# 3    서울특별시 종로구 효자동      175    55.0  ...              NaN   NaN   NaN
# 4    서울특별시 종로구 창성동      165    41.0  ...              NaN   NaN   NaN
# ..             ...      ...     ...  ...              ...   ...   ...
# 466  서울특별시 강동구 둔촌동     8886  1789.0  ...              NaN   4.0  12.0
# 467  서울특별시 강동구 암사동    21898  4452.0  ...              NaN  11.0  40.0
# 468  서울특별시 강동구 성내동    22144  4070.0  ...              NaN  20.0  44.0
# 469  서울특별시 강동구 천호동    26161  4950.0  ...              NaN  21.0  60.0
# 470  서울특별시 강동구 강일동     9593  1708.0  ...              2.0  10.0  21.0
#
# [471 rows x 15 columns]

# %%
df_car_split = df_car['사용본거지법정동명'].str.split(' ')
df_car['동'] = df_car_split.str.get(2)

# %%
df_car
# Out:
#          사용본거지법정동명  동별 총 대수     휘발유      경유  ...  하이브리드\n(CNG+전기)    수소  기타연료    동
# 0    서울특별시 종로구 청운동      800   220.0   259.0  ...              NaN   NaN   2.0  청운동
# 1    서울특별시 종로구 신교동      383    87.0   141.0  ...              NaN   NaN   NaN  신교동
# 2    서울특별시 종로구 궁정동       47    10.0    16.0  ...              NaN   NaN   NaN  궁정동
# 3    서울특별시 종로구 효자동      175    55.0    68.0  ...              NaN   NaN   NaN  효자동
# 4    서울특별시 종로구 창성동      165    41.0    66.0  ...              NaN   NaN   NaN  창성동
# ..             ...      ...     ...     ...  ...              ...   ...   ...  ...
# 466  서울특별시 강동구 둔촌동     8886  1789.0  3108.0  ...              NaN   4.0  12.0  둔촌동
# 467  서울특별시 강동구 암사동    21898  4452.0  7495.0  ...              NaN  11.0  40.0  암사동
# 468  서울특별시 강동구 성내동    22144  4070.0  8188.0  ...              NaN  20.0  44.0  성내동
# 469  서울특별시 강동구 천호동    26161  4950.0  9888.0  ...              NaN  21.0  60.0  천호동
# 470  서울특별시 강동구 강일동     9593  1708.0  3261.0  ...              2.0  10.0  21.0  강일동
#
# [471 rows x 16 columns]

# %%
df_car_nondup = df_car['동'].isin(['노유동', '도동1가', '포이동', '학동'])
df_car = df_car[~df_car_nondup]
df_car
# Out:
#          사용본거지법정동명  동별 총 대수     휘발유      경유  ...  하이브리드\n(CNG+전기)    수소  기타연료    동
# 0    서울특별시 종로구 청운동      800   220.0   259.0  ...              NaN   NaN   2.0  청운동
# 1    서울특별시 종로구 신교동      383    87.0   141.0  ...              NaN   NaN   NaN  신교동
# 2    서울특별시 종로구 궁정동       47    10.0    16.0  ...              NaN   NaN   NaN  궁정동
# 3    서울특별시 종로구 효자동      175    55.0    68.0  ...              NaN   NaN   NaN  효자동
# 4    서울특별시 종로구 창성동      165    41.0    66.0  ...              NaN   NaN   NaN  창성동
# ..             ...      ...     ...     ...  ...              ...   ...   ...  ...
# 466  서울특별시 강동구 둔촌동     8886  1789.0  3108.0  ...              NaN   4.0  12.0  둔촌동
# 467  서울특별시 강동구 암사동    21898  4452.0  7495.0  ...              NaN  11.0  40.0  암사동
# 468  서울특별시 강동구 성내동    22144  4070.0  8188.0  ...              NaN  20.0  44.0  성내동
# 469  서울특별시 강동구 천호동    26161  4950.0  9888.0  ...              NaN  21.0  60.0  천호동
# 470  서울특별시 강동구 강일동     9593  1708.0  3261.0  ...              2.0  10.0  21.0  강일동
#
# [467 rows x 16 columns]

# %%
df_car_sort = df_car.sort_values(by=['동'])
df_car_sort = df_car_sort.reset_index(drop=True)
df_car_sort
# Out:
#           사용본거지법정동명  동별 총 대수     휘발유  ...    수소  기타연료     동
# 0     서울특별시 송파구 가락동    35063  8048.0  ...  14.0  77.0   가락동
# 1    서울특별시 구로구 가리봉동     2800   426.0  ...   NaN   NaN  가리봉동
# 2     서울특별시 금천구 가산동    19894  3035.0  ...   9.0  58.0   가산동
# 3     서울특별시 강서구 가양동    24971  4826.0  ...  19.0  16.0   가양동
# 4     서울특별시 종로구 가회동      289    88.0  ...   NaN   1.0   가회동
# ..              ...      ...     ...  ...   ...   ...   ...
# 462   서울특별시 용산구 후암동     4046   942.0  ...   3.0   1.0   후암동
# 463   서울특별시 종로구 훈정동        1     NaN  ...   NaN   NaN   훈정동
# 464  서울특별시 동대문구 휘경동    10170  1948.0  ...   3.0  17.0   휘경동
# 465   서울특별시 동작구 흑석동     9121  2356.0  ...   5.0   9.0   흑석동
# 466    서울특별시 중구 흥인동      728   211.0  ...   NaN   NaN   흥인동
#
# [467 rows x 16 columns]

# %%
df_map = gpd.read_file('LSMD_ADM_SECT_UMD_11.shp', encoding = 'cp949')

# %%
# 법정동 개수 (서울시 법정동 개수: 467개)

df_map
# Out:
#        EMD_CD EMD_NM  ...   GID                                           geometry
# 0    11110131    권농동  ...  3033  POLYGON ((955214.335 1953251.819, 955216.089 1...
# 1    11110145    송현동  ...  3034  POLYGON ((954272.021 1953376.058, 954272.013 1...
# 2    11110115    사직동  ...  3035  POLYGON ((952745.848 1953334.869, 952758.786 1...
# 3    11110113    필운동  ...  3036  POLYGON ((953189.049 1953363.474, 953191.176 1...
# 4    11110165    이화동  ...  3037  POLYGON ((956562.594 1953426.665, 956562.469 1...
# ..        ...    ...  ...   ...                                                ...
# 462  11650106    잠원동  ...  2663  POLYGON ((955587.808 1946570.634, 955625.913 1...
# 463  11620101    봉천동  ...  2664  POLYGON ((952826.080 1939785.796, 952768.305 1...
# 464  11620102    신림동  ...  2665  POLYGON ((949094.002 1943568.524, 949113.044 1...
# 465  11620103    남현동  ...  2666  POLYGON ((952826.080 1939785.796, 952832.567 1...
# 466  11590101   노량진동  ...  2667  POLYGON ((949838.757 1946405.550, 949841.205 1...
#
# [467 rows x 6 columns]

# %%
# 좌표계 변환
df_map = df_map.to_crs(epsg=4329)
df_map.head()
# Out:
#      EMD_CD EMD_NM  ...   GID                                           geometry
# 0  11110131    권농동  ...  3033  POLYGON ((126.99279 37.57756, 126.99281 37.577...
# 1  11110145    송현동  ...  3034  POLYGON ((126.98212 37.57863, 126.98212 37.578...
# 2  11110115    사직동  ...  3035  POLYGON ((126.96483 37.57818, 126.96498 37.578...
# 3  11110113    필운동  ...  3036  POLYGON ((126.96985 37.57846, 126.96988 37.578...
# 4  11110165    이화동  ...  3037  POLYGON ((127.00805 37.57920, 127.00805 37.579...
#
# [5 rows x 6 columns]

# %%
#동을 오름차순으로 정렬

df_map_sort = df_map.sort_values(by=['EMD_NM'])
df_map_sort = df_map_sort.reset_index(drop=True)
df_map_sort
# Out:
#        EMD_CD EMD_NM  ...   GID                                           geometry
# 0    11710107    가락동  ...  2632  POLYGON ((127.12369 37.50483, 127.12464 37.504...
# 1    11530103   가리봉동  ...  2715  POLYGON ((126.88089 37.48571, 126.88088 37.485...
# 2    11545101    가산동  ...  2711  POLYGON ((126.88457 37.46565, 126.88459 37.465...
# 3    11500104    가양동  ...  2735  POLYGON ((126.84101 37.56842, 126.84090 37.568...
# 4    11110146    가회동  ...  3061  POLYGON ((126.98531 37.58612, 126.98533 37.586...
# ..        ...    ...  ...   ...                                                ...
# 462  11170101    후암동  ...  2901  POLYGON ((126.97655 37.55522, 126.97667 37.555...
# 463  11110150    훈정동  ...  3049  POLYGON ((126.99566 37.57620, 126.99572 37.575...
# 464  11230109    휘경동  ...  2859  POLYGON ((127.05337 37.58771, 127.05344 37.587...
# 465  11590105    흑석동  ...  2671  POLYGON ((126.95461 37.50754, 126.95470 37.507...
# 466  11140163    흥인동  ...  2972  POLYGON ((127.01493 37.56686, 127.01517 37.566...
#
# [467 rows x 6 columns]

# %%
# 서울시 행정동과 자동차 등록현황 병합

df_car_map = pd.concat([df_car_sort, df_map_sort],axis=1)
df_car_map
# Out:
#           사용본거지법정동명  ...                                           geometry
# 0     서울특별시 송파구 가락동  ...  POLYGON ((127.12369 37.50483, 127.12464 37.504...
# 1    서울특별시 구로구 가리봉동  ...  POLYGON ((126.88089 37.48571, 126.88088 37.485...
# 2     서울특별시 금천구 가산동  ...  POLYGON ((126.88457 37.46565, 126.88459 37.465...
# 3     서울특별시 강서구 가양동  ...  POLYGON ((126.84101 37.56842, 126.84090 37.568...
# 4     서울특별시 종로구 가회동  ...  POLYGON ((126.98531 37.58612, 126.98533 37.586...
# ..              ...  ...                                                ...
# 462   서울특별시 용산구 후암동  ...  POLYGON ((126.97655 37.55522, 126.97667 37.555...
# 463   서울특별시 종로구 훈정동  ...  POLYGON ((126.99566 37.57620, 126.99572 37.575...
# 464  서울특별시 동대문구 휘경동  ...  POLYGON ((127.05337 37.58771, 127.05344 37.587...
# 465   서울특별시 동작구 흑석동  ...  POLYGON ((126.95461 37.50754, 126.95470 37.507...
# 466    서울특별시 중구 흥인동  ...  POLYGON ((127.01493 37.56686, 127.01517 37.566...
#
# [467 rows x 22 columns]

# %%
# 안쓰는 행 drop

df_car_map =  df_car_map.drop(['휘발유(유연)',	'휘발유(유연)',	'CNG',	'하이브리드\n(휘발유+전기)',	'하이브리드\n(경유+전기)',	'하이브리드\n(LPG+전기)',	'하이브리드\n(CNG+전기)', '기타연료','SGG_OID', 'COL_ADM_SE', 'GID'],  axis=1)
df_car_map
# Out:
#           사용본거지법정동명  ...                                           geometry
# 0     서울특별시 송파구 가락동  ...  POLYGON ((127.12369 37.50483, 127.12464 37.504...
# 1    서울특별시 구로구 가리봉동  ...  POLYGON ((126.88089 37.48571, 126.88088 37.485...
# 2     서울특별시 금천구 가산동  ...  POLYGON ((126.88457 37.46565, 126.88459 37.465...
# 3     서울특별시 강서구 가양동  ...  POLYGON ((126.84101 37.56842, 126.84090 37.568...
# 4     서울특별시 종로구 가회동  ...  POLYGON ((126.98531 37.58612, 126.98533 37.586...
# ..              ...  ...                                                ...
# 462   서울특별시 용산구 후암동  ...  POLYGON ((126.97655 37.55522, 126.97667 37.555...
# 463   서울특별시 종로구 훈정동  ...  POLYGON ((126.99566 37.57620, 126.99572 37.575...
# 464  서울특별시 동대문구 휘경동  ...  POLYGON ((127.05337 37.58771, 127.05344 37.587...
# 465   서울특별시 동작구 흑석동  ...  POLYGON ((126.95461 37.50754, 126.95470 37.507...
# 466    서울특별시 중구 흥인동  ...  POLYGON ((127.01493 37.56686, 127.01517 37.566...
#
# [467 rows x 12 columns]

# %%
df_car_map.fillna(0)
# Out:
#           사용본거지법정동명  ...                                           geometry
# 0     서울특별시 송파구 가락동  ...  POLYGON ((127.12369 37.50483, 127.12464 37.504...
# 1    서울특별시 구로구 가리봉동  ...  POLYGON ((126.88089 37.48571, 126.88088 37.485...
# 2     서울특별시 금천구 가산동  ...  POLYGON ((126.88457 37.46565, 126.88459 37.465...
# 3     서울특별시 강서구 가양동  ...  POLYGON ((126.84101 37.56842, 126.84090 37.568...
# 4     서울특별시 종로구 가회동  ...  POLYGON ((126.98531 37.58612, 126.98533 37.586...
# ..              ...  ...                                                ...
# 462   서울특별시 용산구 후암동  ...  POLYGON ((126.97655 37.55522, 126.97667 37.555...
# 463   서울특별시 종로구 훈정동  ...  POLYGON ((126.99566 37.57620, 126.99572 37.575...
# 464  서울특별시 동대문구 휘경동  ...  POLYGON ((127.05337 37.58771, 127.05344 37.587...
# 465   서울특별시 동작구 흑석동  ...  POLYGON ((126.95461 37.50754, 126.95470 37.507...
# 466    서울특별시 중구 흥인동  ...  POLYGON ((127.01493 37.56686, 127.01517 37.566...
#
# [467 rows x 12 columns]

# %% [markdown]
# #**지역특성 정보 할당**

# %% [markdown]
# ## **1. 자동차 등록 대수 분석**
#
# ### **인구격자에 자동차등록현황 merge**
#
#
#
#
# 목적: 어느 지역이 가장 많은 자동차가 등록 되어있는지 분석

# %% [markdown]
# #### **인구 격자에 자동차등록 현황, 수소차등록 현황 정보 할당**

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (1.7.1)

# %%
df_pop
# Out:
#             gid     lbl  ...                                     geo_cent grid_id
# 0      다사579454  143.00  ...  POINT (127.0242225272549 37.50736754818467)   00000
# 1      다사613448  235.00  ...  POINT (127.0627225223319 37.50210819142225)   00001
# 2      다사585452   19.00  ...  POINT (127.0310223340312 37.50559202546111)   00002
# 3      다사583456  459.00  ...  POINT (127.0287368798365 37.50918835992229)   00003
# 4      다사585468    9.00  ...  POINT (127.0309320874575 37.52001337639122)   00004
# ...         ...     ...  ...                                          ...     ...
# 64671  다사656567    None  ...  POINT (127.1108132479357 37.60953739424148)   64671
# 64672  다사636570    None  ...  POINT (127.0881387855741 37.61216447014212)   64672
# 64673  다사628533    None  ...   POINT (127.079262473061 37.57878336317809)   64673
# 64674  다사661574    None  ...   POINT (127.116445745636 37.61586524446711)   64674
# 64675  다사622562    None  ...  POINT (127.0723178683743 37.60489744470913)   64675
#
# [64676 rows x 9 columns]

# %%
df_reg = df_pop[['gid','geometry','coordinates','coord_cent','geo_cent','nor_pop']]
df_reg
# Out:
#             gid  ...   nor_pop
# 0      다사579454  ...  0.010851
# 1      다사613448  ...  0.017833
# 2      다사585452  ...  0.001442
# 3      다사583456  ...  0.034831
# 4      다사585468  ...  0.000683
# ...         ...  ...       ...
# 64671  다사656567  ...  0.000000
# 64672  다사636570  ...  0.000000
# 64673  다사628533  ...  0.000000
# 64674  다사661574  ...  0.000000
# 64675  다사622562  ...  0.000000
#
# [64676 rows x 6 columns]

# %%
df_car_map
# Out:
#           사용본거지법정동명  ...                                           geometry
# 0     서울특별시 송파구 가락동  ...  POLYGON ((127.12369 37.50483, 127.12464 37.504...
# 1    서울특별시 구로구 가리봉동  ...  POLYGON ((126.88089 37.48571, 126.88088 37.485...
# 2     서울특별시 금천구 가산동  ...  POLYGON ((126.88457 37.46565, 126.88459 37.465...
# 3     서울특별시 강서구 가양동  ...  POLYGON ((126.84101 37.56842, 126.84090 37.568...
# 4     서울특별시 종로구 가회동  ...  POLYGON ((126.98531 37.58612, 126.98533 37.586...
# ..              ...  ...                                                ...
# 462   서울특별시 용산구 후암동  ...  POLYGON ((126.97655 37.55522, 126.97667 37.555...
# 463   서울특별시 종로구 훈정동  ...  POLYGON ((126.99566 37.57620, 126.99572 37.575...
# 464  서울특별시 동대문구 휘경동  ...  POLYGON ((127.05337 37.58771, 127.05344 37.587...
# 465   서울특별시 동작구 흑석동  ...  POLYGON ((126.95461 37.50754, 126.95470 37.507...
# 466    서울특별시 중구 흥인동  ...  POLYGON ((127.01493 37.56686, 127.01517 37.566...
#
# [467 rows x 12 columns]

# %%
point_cent= gpd.GeoDataFrame(df_reg[['gid','geo_cent']],geometry = 'geo_cent')
point_cent
# Out:
#             gid                    geo_cent
# 0      다사579454  POINT (127.02422 37.50737)
# 1      다사613448  POINT (127.06272 37.50211)
# 2      다사585452  POINT (127.03102 37.50559)
# 3      다사583456  POINT (127.02874 37.50919)
# 4      다사585468  POINT (127.03093 37.52001)
# ...         ...                         ...
# 64671  다사656567  POINT (127.11081 37.60954)
# 64672  다사636570  POINT (127.08814 37.61216)
# 64673  다사628533  POINT (127.07926 37.57878)
# 64674  다사661574  POINT (127.11645 37.61587)
# 64675  다사622562  POINT (127.07232 37.60490)
#
# [64676 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
## 1시간 이상 소요되므로 '자동차등록_동_수소_포함.geojson'으로 저장된 파일 활용

# car_points = []
# dong_points = []
# h2car_points = []
# for i in tqdm(range(len(df_car_map))):
#     car_points.append([df_car_map.loc[i,'동별 총 대수'],
#                         point_cent.buffer(0.00000001).within(df_car_map.loc[i,'geometry'])])
    
#     h2car_points.append([df_car_map.loc[i,'수소'],
#                         point_cent.buffer(0.00000001).within(df_car_map.loc[i,'geometry'])])
    
#     dong_points.append([df_car_map.loc[i,'동'],
#                         point_cent.buffer(0.00000001).within(df_car_map.loc[i,'geometry'])])

# df_reg['동'] = 0    
# df_reg['자동차등록'] = 0
# df_reg['수소자동차등록'] = 0

# for i in range(len(car_points)):
#     df_reg['자동차등록'][car_points[i][1]] = car_points[i][0]
#     df_reg['동'][dong_points[i][1]] = dong_points[i][0]
#     df_reg['수소자동차등록'][h2car_points[i][1]] = h2car_points[i][0]
    
# df_reg

# %% [markdown]
# **자동차 등록대수 geojson 불러온 뒤 읽음**

# %%
## 미리 저장해둔 자동차등록현황, 수소차등록현황 불러오기
df_reg_car = gpd.read_file('자동차등록_동_수소_포함.geojson', encoding = 'cp949')

# %%
df_reg_car
# Out:
#             gid  자동차등록  ...    동                                           geometry
# 0      다사579454  20953  ...  논현동  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1      다사613448  39094  ...  대치동  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2      다사585452  37861  ...  역삼동  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3      다사583456  20953  ...  논현동  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4      다사585468  20953  ...  논현동  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...         ...    ...  ...  ...                                                ...
# 64671  다사656567  14815  ...  망우동  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672  다사636570  19808  ...  신내동  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673  다사628533  37518  ...  면목동  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674  다사661574  19808  ...  신내동  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675  다사622562  11839  ...  중화동  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 5 columns]

# %%
dong = df_reg_car['동'].value_counts()
dong
# Out:
# 신림동      1861
# 상계동      1609
# 0        1178
# 진관동      1168
# 도봉동       976
#          ...
# 장교동         2
# 수표동         2
# 회현동3가       1
# 수하동         1
# 남학동         1
# Name: 동, Length: 466, dtype: int64

# %%
dong.to_csv('dong.csv', encoding='cp949')

# %%
dong= pd.read_csv('dong.csv',  encoding='cp949')
dong
# Out:
#     Unnamed: 0     동
# 0          신림동  1861
# 1          상계동  1609
# 2            0  1178
# 3          진관동  1168
# 4          도봉동   976
# ..         ...   ...
# 461        장교동     2
# 462        수표동     2
# 463      회현동3가     1
# 464        수하동     1
# 465        남학동     1
#
# [466 rows x 2 columns]

# %%
dong.columns = ['동', '격자 개수'] # 칼람명 바꾸기

# %%
df_reg_car_dong = pd.merge(df_reg_car,dong, how='left', on='동')
df_reg_car_dong
# Out:
#             gid  ...  격자 개수
# 0      다사579454  ...    277
# 1      다사613448  ...    388
# 2      다사585452  ...    358
# 3      다사583456  ...    277
# 4      다사585468  ...    277
# ...         ...  ...    ...
# 64671  다사656567  ...    388
# 64672  다사636570  ...    358
# 64673  다사628533  ...    627
# 64674  다사661574  ...    358
# 64675  다사622562  ...    177
#
# [64676 rows x 6 columns]

# %%
df_reg_car_dong['자동차등록_grid'] = df_reg_car_dong['자동차등록']/df_reg_car_dong['격자 개수']

# %%
df_reg_car_dong['수소차등록_grid'] = df_reg_car_dong['수소자동차등록']/df_reg_car_dong['격자 개수']

# %%
df_reg_car_dong.head()
# Out:
#         gid  자동차등록  수소자동차등록  ... 격자 개수  자동차등록_grid  수소차등록_grid
# 0  다사579454  20953        9  ...   277   75.642599    0.032491
# 1  다사613448  39094       17  ...   388  100.757732    0.043814
# 2  다사585452  37861       12  ...   358  105.756983    0.033520
# 3  다사583456  20953        9  ...   277   75.642599    0.032491
# 4  다사585468  20953        9  ...   277   75.642599    0.032491
#
# [5 rows x 8 columns]

# %%
df_reg_car
# Out:
#             gid  자동차등록  ...    동                                           geometry
# 0      다사579454  20953  ...  논현동  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1      다사613448  39094  ...  대치동  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2      다사585452  37861  ...  역삼동  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3      다사583456  20953  ...  논현동  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4      다사585468  20953  ...  논현동  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...         ...    ...  ...  ...                                                ...
# 64671  다사656567  14815  ...  망우동  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672  다사636570  19808  ...  신내동  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673  다사628533  37518  ...  면목동  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674  다사661574  19808  ...  신내동  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675  다사622562  11839  ...  중화동  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 5 columns]

# %% [markdown]
# ## **2. 기존 LPG 충전소 위치 분석**
#
#
# * LPG 충전소는 2km를 커버할 수 있다고 가정.

# %% [markdown]
# ### **기존 LPG 좌표 추출(coverage distance 고려)**

# %%
cover_dist = int(input())
2000 # meter
# Out:
# 2000
# 2000

# %%
from shapely.geometry import Polygon, Point

# %%
df_lpg = pd.read_csv('전국_LPG충전소_현황_경도위도.csv')

# %%
df_lpg = df_lpg[df_lpg['행정 구역'].str.contains('서울')]
df_lpg
# Out:
#      행정 구역           업소명  ...          경도         위도
# 0   서울 강남구       강남복지충전소  ...  127.105495  37.476386
# 1   서울 강남구       (주)진양가스  ...  127.035691  37.490497
# 2   서울 강남구     대치에너지주식회사  ...  127.078101  37.499342
# 3   서울 강남구      남서울가스(주)  ...  127.075564  37.497799
# 4   서울 강남구      (주)수서에너지  ...  127.113228  37.481193
# ..     ...           ...  ...         ...        ...
# 74  서울 은평구       은평서부충전소  ...  126.921229  37.643674
# 75  서울 중랑구      신내LPG충전소  ...  127.098130  37.613902
# 76  서울 중랑구      (주)풍림에너지  ...  127.079308  37.579608
# 77  서울 중랑구  동일석유(주)황금충전소  ...  127.075901  37.594187
# 78  서울 중랑구         망우충전소  ...  127.101915  37.600587
#
# [79 rows x 8 columns]

# %%
shapely.speedups.enable()

# %%
# 기존 LPG 충전소가 커버하는 위치 

df_lpg_geo = []
for i in range(len(df_lpg)):
   df_lpg_geo.append([df_lpg.loc[i,'업소명'],Point(df_lpg.loc[i,'경도'],df_lpg.loc[i,'위도']).buffer(cover_dist/0.9*0.00001)]) # 총 직경 2km 커버(10000/0.9*0.00001 = 0.0022)

# %%
# df_lpg 좌표 생성

df_lpg_geo = pd.DataFrame(df_lpg_geo )
df_lpg_geo.columns = ["업소명", "geometry"]
point_cent.buffer(0.00000001).within(df_lpg_geo.loc[i,'geometry'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64671     True
# 64672     True
# 64673    False
# 64674     True
# 64675    False
# Length: 64676, dtype: bool

# %%
## 1시간 이상 소요되므로 "LPG_2km.geojson"으로 미리 저장한 파일 활용

# LPG_points = []
# for i in tqdm(range(len(df_lpg_geo))):
#     LPG_points.append(point_cent.buffer(0.00000001).within(df_lpg_geo.loc[i,'geometry']))  
  

# df_reg['LPG_충전소'] = 0

# for i in range(len(LPG_points)):
#     df_reg['LPG_충전소'][LPG_points[i]] = 1  # 행정동이 아닌 grid에 맞춰 LPG 할당
# df_reg

# %%
# df_reg[['geometry', 'LPG_충전소']].to_file("LPG_2km.geojson", driver="GeoJSON")

# %% [markdown]
# **LPG 충전소 geojson 파일 업로드**

# %%
## 미리 저장해둔 "LPG_2km.geojson"파일 읽기 불러오기
df_reg_lpg = gpd.read_file('LPG_2km.geojson', encoding = 'cp949')

# %%
df_reg_lpg
# Out:
#        LPG_충전소                                           geometry
# 0            1  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1            1  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2            1  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3            1  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4            1  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...        ...                                                ...
# 64671        1  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672        1  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673        1  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674        1  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675        1  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 2 columns]

# %%
df_reg_lpg.columns
# Out:
# Index(['LPG_충전소', 'geometry'], dtype='object')

# %%
df_reg_lpg = df_reg_lpg.drop(['geometry'],  axis=1)

# %%
df_reg_lpg
# Out:
#        LPG_충전소
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 64671        1
# 64672        1
# 64673        1
# 64674        1
# 64675        1
#
# [64676 rows x 1 columns]

# %% [markdown]
# ### **기존 LPG 좌표 추출(coverage distance 고려안함)**

# %%
df_lpg_nb = pd.read_csv('전국_LPG충전소_현황_경도위도.csv')

# %%
df_lpg_nb = df_lpg_nb[df_lpg_nb['행정 구역'].str.contains('서울')]
df_lpg_nb
# Out:
#      행정 구역           업소명  ...          경도         위도
# 0   서울 강남구       강남복지충전소  ...  127.105495  37.476386
# 1   서울 강남구       (주)진양가스  ...  127.035691  37.490497
# 2   서울 강남구     대치에너지주식회사  ...  127.078101  37.499342
# 3   서울 강남구      남서울가스(주)  ...  127.075564  37.497799
# 4   서울 강남구      (주)수서에너지  ...  127.113228  37.481193
# ..     ...           ...  ...         ...        ...
# 74  서울 은평구       은평서부충전소  ...  126.921229  37.643674
# 75  서울 중랑구      신내LPG충전소  ...  127.098130  37.613902
# 76  서울 중랑구      (주)풍림에너지  ...  127.079308  37.579608
# 77  서울 중랑구  동일석유(주)황금충전소  ...  127.075901  37.594187
# 78  서울 중랑구         망우충전소  ...  127.101915  37.600587
#
# [79 rows x 8 columns]

# %%
shapely.speedups.enable()

# %%
# 기존 LPG 충전소 위치 

df_lpg_nb_geo = []
for i in range(len(df_lpg_nb)):
   df_lpg_nb_geo.append([df_lpg_nb.loc[i,'업소명'],Point(df_lpg_nb.loc[i,'경도'],df_lpg_nb.loc[i,'위도']).buffer(0.00054)]) 
   ## LPG 충전소 79개가 추출될 수 있도록 조정된 buffer 값 0.00054

# %%
# df_lpg 좌표 생성

df_lpg_nb_geo = pd.DataFrame(df_lpg_nb_geo )
df_lpg_nb_geo.columns = ["업소명", "geometry"]
# point_cent.buffer(0.00000001).within(df_lpg_nb_geo.loc[i,'geometry'])

# %%
## 1시간 이상 소요되므로 "LPG_노버퍼.geojson"으로 미리 저장한 파일 활용

# LPG_nb_points = []
# for i in tqdm(range(len(df_lpg_nb_geo))):
#     LPG_nb_points.append(point_cent.buffer(0.00000001).within(df_lpg_nb_geo.loc[i,'geometry']))  
  

# df_reg['LPG_충전소_nb'] = 0

# for i in range(len(LPG_nb_points)):
#     df_reg['LPG_충전소_nb'][LPG_nb_points[i]] = 1  
# df_reg

# %%
# df_reg['LPG_충전소_nb'].value_counts()

# %%
# df_reg[['geometry', 'LPG_충전소_nb']].to_file("LPG_노버퍼.geojson", driver="GeoJSON")

# %% [markdown]
# **LPG no buffer geojson으로 불러오기**

# %%
## "LPG_노버퍼.geojson"으로 미리 저장한 파일 
df_reg_lpg_nb = gpd.read_file('LPG_노버퍼.geojson', encoding = 'cp949')

# %%
df_reg_lpg_nb
# Out:
#        LPG_충전소_nb                                           geometry
# 0               0  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1               0  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2               0  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3               0  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4               0  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...           ...                                                ...
# 64671           0  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672           0  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673           0  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674           0  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675           0  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 2 columns]

# %%
df_reg_lpg_nb= df_reg_lpg_nb.drop(['geometry'], axis=1)

# %%
df_reg_lpg_nb.value_counts()
# Out:
# LPG_충전소_nb
# 0             64597
# 1                79
# dtype: int64

# %% [markdown]
# ## **3. 기존 수소충전소 위치 분석**

# %%
df_h2 = pd.read_csv('H2_long_lat.csv', encoding='cp949')

# %%
df_h2 = df_h2[df_h2['주소'].str.contains('서울')]
df_h2
# Out:
#     No                   충전소명   구분  ...          경도         위도 CLSS
# 24  40          강동구 상일동 수소충전소  저장식  ...  127.170523  37.545251  정좌표
# 25   7         서울특별시 상암수소스테이션  제조식  ...  126.881034  37.571335  정좌표
# 26   6     현대자동차㈜ 양재그린에너지스테이션  저장식  ...  127.034450  37.468303  정좌표
# 27  34  수소에너지네트워크(주) 국회 수소충전소  저장식  ...  126.916537  37.530516  정좌표
#
# [4 rows x 12 columns]

# %%
df_h2 = df_h2.reset_index(drop=True)
df_h2
# Out:
#    No                   충전소명   구분  ...          경도         위도 CLSS
# 0  40          강동구 상일동 수소충전소  저장식  ...  127.170523  37.545251  정좌표
# 1   7         서울특별시 상암수소스테이션  제조식  ...  126.881034  37.571335  정좌표
# 2   6     현대자동차㈜ 양재그린에너지스테이션  저장식  ...  127.034450  37.468303  정좌표
# 3  34  수소에너지네트워크(주) 국회 수소충전소  저장식  ...  126.916537  37.530516  정좌표
#
# [4 rows x 12 columns]

# %%
df_h2_geo = []
for i in range(len(df_h2)):
   df_h2_geo.append([df_h2.loc[i,'충전소명'],Point(df_h2.loc[i,'경도'],df_h2.loc[i,'위도']).buffer(cover_dist/0.9*0.00001)]) # 총 직경 2km 커버(10000/0.9*0.00001 = 0.0022)

# %%
df_h2_geo = pd.DataFrame(df_h2_geo)
df_h2_geo.columns = ['충전소명', 'geometry']
df_h2_geo
# Out:
#                     충전소명                                           geometry
# 0          강동구 상일동 수소충전소  POLYGON ((127.1927450222222 37.5452509, 127.19...
# 1         서울특별시 상암수소스테이션  POLYGON ((126.9032564222222 37.571335, 126.903...
# 2     현대자동차㈜ 양재그린에너지스테이션  POLYGON ((127.0566722222222 37.4683032, 127.05...
# 3  수소에너지네트워크(주) 국회 수소충전소  POLYGON ((126.9387589222222 37.530516, 126.938...

# %%
## 미리 저장된 "수소충전소_2km.geojson" 파일 활용
# h2_points = []
# for i in tqdm(range(len(df_h2_geo))):
#     h2_points.append(point_cent.buffer(0.00000001).within(df_h2_geo.loc[i,'geometry'])) 
  

# df_reg['수소충전소'] = 0

# for i in range(len(h2_points)):
#     df_reg['수소충전소'][h2_points[i]] = 1   #행정동이 아닌 grid에 맞춰 수소충전소 할당
# df_reg

# %%
# df_reg[['geometry', '수소충전소']].to_file("수소충전소_2km.geojson", driver="GeoJSON")

# %% [markdown]
# **수소충전소 geojson으로 불러오기**

# %%
## 미리 저장된 "수소충전소_2km.geojson" 파일 불러오기
df_reg_h2station = gpd.read_file('수소충전소_2km.geojson', encoding = 'cp949')

# %%
df_reg_h2station
# Out:
#        수소충전소                                           geometry
# 0          0  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1          0  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2          0  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3          0  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4          0  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...      ...                                                ...
# 64671      0  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672      0  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673      0  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674      0  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675      0  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 2 columns]

# %%
df_reg_h2station = df_reg_h2station.drop(['geometry'], axis=1)

# %%
# df_reg['수소충전소'].value_counts()

# %% [markdown]
# ## **4. 제 1종 보호시설**
#
# - 초중고등학교 (반경 17M)
# - 어린이집 (반경 17M)

# %% [markdown]
# ### 초등고등학교 좌표 추출

# %%
df_school = pd.read_csv('ele_mid_long_lat.csv', encoding='utf-8')

# %%
df_school
# Out:
#         학교종류명 설립구분                학교명  ...       X        Y CLSS
# 0     각종학교(중)   사립            선화예술중학교  ...  963576  1950201  정좌표
# 1        초등학교   공립           서울숭신초등학교  ...  958301  1952135  정좌표
# 2         중학교   공립              행당중학교  ...  959570  1950660  정좌표
# 3         중학교   사립     한양대학교사범대학부속중학교  ...  959641  1951437  정좌표
# 4         중학교   공립              자양중학교  ...  962411  1948530  정좌표
# ...       ...  ...                ...  ...     ...      ...  ...
# 1414     고등학교   국립           국립국악고등학교  ...  960355  1941970  정좌표
# 1415     특수학교   국립             한국우진학교  ...  947334  1952599  정좌표
# 1416     특수학교   국립              서울농학교  ...  953076  1954105  정좌표
# 1417     특수학교   국립              서울맹학교  ...  953000  1954043  정좌표
# 1418    공동실습소   공립  경기기계공업고등학교부설공동실습소  ...  962485  1959412  정좌표
#
# [1419 rows x 12 columns]

# %%
df_school = df_school[df_school['도로명주소'].str.contains('서울')]
df_school
# Out:
#         학교종류명 설립구분                학교명  ...       X        Y CLSS
# 0     각종학교(중)   사립            선화예술중학교  ...  963576  1950201  정좌표
# 1        초등학교   공립           서울숭신초등학교  ...  958301  1952135  정좌표
# 2         중학교   공립              행당중학교  ...  959570  1950660  정좌표
# 3         중학교   사립     한양대학교사범대학부속중학교  ...  959641  1951437  정좌표
# 4         중학교   공립              자양중학교  ...  962411  1948530  정좌표
# ...       ...  ...                ...  ...     ...      ...  ...
# 1414     고등학교   국립           국립국악고등학교  ...  960355  1941970  정좌표
# 1415     특수학교   국립             한국우진학교  ...  947334  1952599  정좌표
# 1416     특수학교   국립              서울농학교  ...  953076  1954105  정좌표
# 1417     특수학교   국립              서울맹학교  ...  953000  1954043  정좌표
# 1418    공동실습소   공립  경기기계공업고등학교부설공동실습소  ...  962485  1959412  정좌표
#
# [1419 rows x 12 columns]

# %%
df_school= df_school.reset_index(drop=True)
df_school
# Out:
#         학교종류명 설립구분                학교명  ...       X        Y CLSS
# 0     각종학교(중)   사립            선화예술중학교  ...  963576  1950201  정좌표
# 1        초등학교   공립           서울숭신초등학교  ...  958301  1952135  정좌표
# 2         중학교   공립              행당중학교  ...  959570  1950660  정좌표
# 3         중학교   사립     한양대학교사범대학부속중학교  ...  959641  1951437  정좌표
# 4         중학교   공립              자양중학교  ...  962411  1948530  정좌표
# ...       ...  ...                ...  ...     ...      ...  ...
# 1414     고등학교   국립           국립국악고등학교  ...  960355  1941970  정좌표
# 1415     특수학교   국립             한국우진학교  ...  947334  1952599  정좌표
# 1416     특수학교   국립              서울농학교  ...  953076  1954105  정좌표
# 1417     특수학교   국립              서울맹학교  ...  953000  1954043  정좌표
# 1418    공동실습소   공립  경기기계공업고등학교부설공동실습소  ...  962485  1959412  정좌표
#
# [1419 rows x 12 columns]

# %%
df_school_geo = []
for i in range(len(df_school)):
   df_school_geo.append([df_school.loc[i,'학교명'],Point(df_school.loc[i,'경도'],df_school.loc[i,'위도']).buffer(0.00019)]) # 수소충전소 고압가스 규제 : 1종 보호시설로 부터 17m 이상의 안전거리를 유지할 것 : 17/0.9*0.00001 = 0.00018888... ~0.00019

# %%
df_school_geo = pd.DataFrame(df_school_geo)
df_school_geo.columns = ['학교명', 'geometry']
df_school_geo
# Out:
#                     학교명                                           geometry
# 0               선화예술중학교  POLYGON ((127.087836 37.5504333, 127.087835085...
# 1              서울숭신초등학교  POLYGON ((127.0280049 37.56764329999999, 127.0...
# 2                 행당중학교  POLYGON ((127.0424599 37.554408, 127.042458985...
# 3        한양대학교사범대학부속중학교  POLYGON ((127.0432192 37.56140629999999, 127.0...
# 4                 자양중학교  POLYGON ((127.0747363 37.535329, 127.074735385...
# ...                 ...                                                ...
# 1414           국립국악고등학교  POLYGON ((127.0518151 37.47611029999999, 127.0...
# 1415             한국우진학교  POLYGON ((126.9037977 37.5712585, 126.90379678...
# 1416              서울농학교  POLYGON ((126.96872 37.5851429, 126.9687190850...
# 1417              서울맹학교  POLYGON ((126.9678672 37.58458579999999, 126.9...
# 1418  경기기계공업고등학교부설공동실습소  POLYGON ((127.0750169 37.6334094, 127.07501598...
#
# [1419 rows x 2 columns]

# %%
## 1시간 이상 소요되어 미리 저장해둔 "학교_포함.geojson" 활용
# school_points = []
# for i in tqdm(range(len(df_school_geo))):
#     school_points.append(point_cent.buffer(0.00000001).within(df_school_geo.loc[i,'geometry'])) 
  

# df_reg['초중고등학교'] = 0

# for i in range(len(school_points)):
#     df_reg['초중고등학교'][school_points[i]] = 1   #행정동이 아닌 grid에 맞춰 학교 할당
# df_reg

# %%
# df_reg['초중고등학교'].value_counts()

# %%
# df_reg.to_csv('df_reg_초중고.csv', encoding='utf-8')

# %% [markdown]
# **학교 geojson 불러오기**

# %%
## 미리 저장해둔 "학교_포함.geojson" 불러오기
df_reg_school = gpd.read_file('학교_포함.geojson', encoding = 'cp949')

# %%
df_reg_school
# Out:
#             gid  ...                                           geometry
# 0      다사579454  ...  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1      다사613448  ...  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2      다사585452  ...  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3      다사583456  ...  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4      다사585468  ...  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...         ...  ...                                                ...
# 64671  다사656567  ...  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672  다사636570  ...  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673  다사628533  ...  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674  다사661574  ...  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675  다사622562  ...  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 4 columns]

# %%
df_reg_school = df_reg_school.drop(['gid', 'nomalized_pop', 'geometry'], axis=1)

# %% [markdown]
# ### 어린이집 좌표 추출

# %%
df_kid = pd.read_csv('kids_long_lat.csv', encoding='utf-8')

# %%
df_kid
# Out:
#            교육청명             유치원명      설립유형  ...       X        Y  CLSS
# 0     서울특별시교육청    서울정심초등학교병설유치원    공립(병설)   ...  947681  1941552   정좌표
# 1     서울특별시교육청         서울솔방울유치원    공립(단설)   ...  966184  1945134   정좌표
# 2     서울특별시교육청           란키즈유치원    사립(사인)   ...  966959  1942458   정좌표
# 3     서울특별시교육청    서울신현초등학교병설유치원    공립(병설)   ...  964117  1956340   정좌표
# 4     서울특별시교육청           다우림유치원    사립(사인)   ...  948122  1955365   정좌표
# ..          ...              ...       ...  ...     ...      ...   ...
# 907   서울특별시교육청    서울강솔초등학교병설유치원    공립(병설)   ...  971768  1951463   정좌표
# 908   서울특별시교육청    서울학동초등학교병설유치원    공립(병설)   ...  959307  1945985   정좌표
# 909   서울특별시교육청    서울가양초등학교병설유치원    공립(병설)   ...  943355  1951576   정좌표
# 910   서울특별시교육청    서울송파초등학교병설유치원    공립(병설)   ...  965616  1945388   정좌표
# 911   서울특별시교육청    서울등명초등학교병설유치원    공립(병설)   ...  941930  1951471   정좌표
#
# [912 rows x 21 columns]

# %%
df_kid  =  df_kid .drop(['운영시간',	'만3세학급수',	'만4세학급수',	'만5세학급수',	'혼합학급수',	'특수학급수',	'만3세유아수',	'만4세유아수',	'만5세유아수',	'혼합유아수',	'특수유아수',	'공시차수'],  axis=1)
df_kid
# Out:
#            교육청명             유치원명      설립유형  ...       X        Y  CLSS
# 0     서울특별시교육청    서울정심초등학교병설유치원    공립(병설)   ...  947681  1941552   정좌표
# 1     서울특별시교육청         서울솔방울유치원    공립(단설)   ...  966184  1945134   정좌표
# 2     서울특별시교육청           란키즈유치원    사립(사인)   ...  966959  1942458   정좌표
# 3     서울특별시교육청    서울신현초등학교병설유치원    공립(병설)   ...  964117  1956340   정좌표
# 4     서울특별시교육청           다우림유치원    사립(사인)   ...  948122  1955365   정좌표
# ..          ...              ...       ...  ...     ...      ...   ...
# 907   서울특별시교육청    서울강솔초등학교병설유치원    공립(병설)   ...  971768  1951463   정좌표
# 908   서울특별시교육청    서울학동초등학교병설유치원    공립(병설)   ...  959307  1945985   정좌표
# 909   서울특별시교육청    서울가양초등학교병설유치원    공립(병설)   ...  943355  1951576   정좌표
# 910   서울특별시교육청    서울송파초등학교병설유치원    공립(병설)   ...  965616  1945388   정좌표
# 911   서울특별시교육청    서울등명초등학교병설유치원    공립(병설)   ...  941930  1951471   정좌표
#
# [912 rows x 9 columns]

# %%
df_kid  = df_kid [df_kid['주소'].str.contains('서울')]
df_kid
# Out:
#            교육청명             유치원명      설립유형  ...       X        Y  CLSS
# 0     서울특별시교육청    서울정심초등학교병설유치원    공립(병설)   ...  947681  1941552   정좌표
# 1     서울특별시교육청         서울솔방울유치원    공립(단설)   ...  966184  1945134   정좌표
# 2     서울특별시교육청           란키즈유치원    사립(사인)   ...  966959  1942458   정좌표
# 3     서울특별시교육청    서울신현초등학교병설유치원    공립(병설)   ...  964117  1956340   정좌표
# 4     서울특별시교육청           다우림유치원    사립(사인)   ...  948122  1955365   정좌표
# ..          ...              ...       ...  ...     ...      ...   ...
# 907   서울특별시교육청    서울강솔초등학교병설유치원    공립(병설)   ...  971768  1951463   정좌표
# 908   서울특별시교육청    서울학동초등학교병설유치원    공립(병설)   ...  959307  1945985   정좌표
# 909   서울특별시교육청    서울가양초등학교병설유치원    공립(병설)   ...  943355  1951576   정좌표
# 910   서울특별시교육청    서울송파초등학교병설유치원    공립(병설)   ...  965616  1945388   정좌표
# 911   서울특별시교육청    서울등명초등학교병설유치원    공립(병설)   ...  941930  1951471   정좌표
#
# [912 rows x 9 columns]

# %%
df_kid_geo = []
for i in range(len(df_kid)):
   df_kid_geo.append([df_kid.loc[i,'유치원명'],Point(df_kid.loc[i,'경도'],df_kid.loc[i,'위도']).buffer(0.00019)]) # 수소충전소 고압가스 규제 : 1종 보호시설로 부터 17m 이상의 안전거리를 유지할 것 : 17/0.9*0.00001 = 0.00018888... ~0.00019

# %%
df_kid_geo = pd.DataFrame(df_kid_geo)
df_kid_geo.columns = ['유치원명', 'geometry']
df_kid_geo
# Out:
#                 유치원명                                           geometry
# 0     서울정심초등학교병설유치원   POLYGON ((126.9085094 37.4717104, 126.90850848...
# 1          서울솔방울유치원   POLYGON ((127.1175941 37.5048591, 127.11759318...
# 2            란키즈유치원   POLYGON ((127.1264819 37.4807678, 127.12648098...
# 3     서울신현초등학교병설유치원   POLYGON ((127.0936612 37.6057842, 127.09366028...
# 4            다우림유치원   POLYGON ((126.9125245 37.5962346, 126.91252358...
# ..               ...                                                ...
# 907   서울강솔초등학교병설유치원   POLYGON ((127.180532 37.56209699999999, 127.18...
# 908   서울학동초등학교병설유치원   POLYGON ((127.0397411 37.512253, 127.039740185...
# 909   서울가양초등학교병설유치원   POLYGON ((126.8588199 37.5618039, 126.85881898...
# 910   서울송파초등학교병설유치원   POLYGON ((127.1111543 37.5071265, 127.11115338...
# 911   서울등명초등학교병설유치원   POLYGON ((126.8426954 37.5607729, 126.84269448...
#
# [912 rows x 2 columns]

# %%
## 1시간 이상 소요되어 미리 저장해둔'유치원_포함.geojson' 파일 활용
# kid_points = []
# for i in tqdm(range(len(df_kid_geo))):
#     kid_points .append(point_cent.buffer(0.00000001).within(df_kid_geo.loc[i,'geometry'])) 
  

# df_reg['유치원'] = 0

# for i in range(len(kid_points )):
#     df_reg['유치원'][kid_points [i]] = 1   #행정동이 아닌 grid에 맞춰 유치원 할당
# df_reg

# %%
# df_reg[['gid','geometry','nor_pop', '유치원']].to_file("유치원_포함.geojson", driver="GeoJSON")

# %%
# df_reg['유치원'].value_counts()

# %% [markdown]
# **유치원 geojson 파일 불러오기**

# %%
## 미리 저장해둔'유치원_포함.geojson' 파일 불러오기
df_reg_kids = gpd.read_file('유치원_포함.geojson', encoding = 'cp949')

# %%
df_reg_kids
# Out:
#             gid  ...                                           geometry
# 0      다사579454  ...  POLYGON ((127.02366 37.50691, 127.02365 37.507...
# 1      다사613448  ...  POLYGON ((127.06216 37.50166, 127.06215 37.502...
# 2      다사585452  ...  POLYGON ((127.03046 37.50514, 127.03045 37.506...
# 3      다사583456  ...  POLYGON ((127.02817 37.50874, 127.02817 37.509...
# 4      다사585468  ...  POLYGON ((127.03037 37.51956, 127.03036 37.520...
# ...         ...  ...                                                ...
# 64671  다사656567  ...  POLYGON ((127.11025 37.60908, 127.11024 37.609...
# 64672  다사636570  ...  POLYGON ((127.08757 37.61171, 127.08757 37.612...
# 64673  다사628533  ...  POLYGON ((127.07870 37.57833, 127.07869 37.579...
# 64674  다사661574  ...  POLYGON ((127.11588 37.61541, 127.11588 37.616...
# 64675  다사622562  ...  POLYGON ((127.07175 37.60444, 127.07175 37.605...
#
# [64676 rows x 4 columns]

# %%
df_reg_kids = df_reg_kids.drop(['gid', 'nor_pop', 'geometry'], axis =1)
df_reg_kids
# Out:
#        유치원
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 64671    0
# 64672    0
# 64673    0
# 64674    0
# 64675    0
#
# [64676 rows x 1 columns]

# %% [markdown]
# ## **지역특성 요소 Concate**

# %%
df_reg_car_dong = df_reg_car_dong.drop(['geometry'], axis=1)

# %%
df_total_con = pd.concat([df_reg, df_reg_lpg, df_reg_kids, df_reg_school, df_reg_h2station, df_reg_car_dong, df_reg_lpg_nb], axis=1)

# %%
df_total_con ['nor_h2car'] = df_total_con ['수소차등록_grid'] / df_total_con ['수소차등록_grid'].max()

# %%
df_total_con ['nor_car'] = df_total_con ['자동차등록_grid'] / df_total_con ['자동차등록_grid'].max()

# %%
df_total_con
# Out:
#             gid  ...   nor_car
# 0      다사579454  ...  0.114714
# 1      다사613448  ...  0.152802
# 2      다사585452  ...  0.160384
# 3      다사583456  ...  0.114714
# 4      다사585468  ...  0.114714
# ...         ...  ...       ...
# 64671  다사656567  ...  0.057906
# 64672  다사636570  ...  0.083909
# 64673  다사628533  ...  0.090745
# 64674  다사661574  ...  0.083909
# 64675  다사622562  ...  0.101436
#
# [64676 rows x 20 columns]

# %%
df_total_con.columns
# Out:
# Index(['gid', 'geometry', 'coordinates', 'coord_cent', 'geo_cent', 'nor_pop',
#        'LPG_충전소', '유치원', '학교', '수소충전소', 'gid', '자동차등록', '수소자동차등록', '동',
#        '격자 개수', '자동차등록_grid', '수소차등록_grid', 'LPG_충전소_nb', 'nor_h2car',
#        'nor_car'],
#       dtype='object')

# %% [markdown]
# # **가중치 산정**

# %% [markdown]
# ## **충전소 위치선정에 대한 영향 요소 분석**

# %% [markdown]
# **충전소 위치선정에 대한 영향 요소 분석**
#
# 수소차 충전소 위치 선정을 최적화 문제로 풀 것이다. 이를 위해 목적함수가 필요하며 다음과 같은 기준으로 식을 세웠다.
#
# **가정**
#
# 수소차 충전소 위치는 인구현황, 자동차 등록대수, 자동차 등록대수만 고려하여 위치를 선정한다. 기존 설치된 전기자동차 충전소는 위 고려사항을 충분히 고려하여 만들어진 곳이다.
#
#
#
# **분석 방법**
#
# 고려되는 모든 변수들은 정규화 하였다.
# 로지스틱 회귀분석(Logistic Regression)을 이용해 수소자동차 충전소 위치에 영향을 주는 요소의 관계를 분석하였다.
#
# 분석 Input: (정규화된) 인구현황, 자동차 등록대수, 수소차 등록대수
#
# 분석 Output: 고려되는 요소들과 각 충전소 사이의 상관계수

# %%
df_total_con = df_total_con.fillna(0)

# %%
df_total_con.rename(columns = {'LPG_충전소' : 'LPG'}, inplace= True)

# %%
df_total_con.head(3)
# Out:
#         gid  ...   nor_car
# 0  다사579454  ...  0.114714
# 1  다사613448  ...  0.152802
# 2  다사585452  ...  0.160384
#
# [3 rows x 20 columns]

# %%
# objective function 만들기

from sklearn.linear_model import LogisticRegression
from sklearn import linear_model


# 로지스틱 회귀분석
X = df_total_con[["nor_pop","nor_car", "nor_h2car"]] #변수 여러개
y = df_total_con[["LPG"]]


# 검정
logreg = linear_model.LogisticRegression()
logreg.fit(X, y)
LPG_coeff = logreg.coef_
print('LPG 충전소 Intercept: ', logreg.intercept_)
print('LPG Coefficients: \n', LPG_coeff)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LPG 충전소 Intercept:  [0.04919151]
# LPG Coefficients:
#  [[ 9.87745395 14.94089995  0.16966643]]

# %%
X.corr()
# Out:
#             nor_pop   nor_car  nor_h2car
# nor_pop    1.000000  0.330004   0.112730
# nor_car    0.330004  1.000000   0.489976
# nor_h2car  0.112730  0.489976   1.000000

# %%
df_total_con['w'] = 0 
df_total_con['w'] = (LPG_coeff[0][0]*df_total_con['nor_pop']+
                     LPG_coeff[0][1]*df_total_con['nor_car']+
                     LPG_coeff[0][2]*df_total_con['nor_h2car'])

# %%
df_total_con['w']
# Out:
# 0        1.826632
# 1        2.466578
# 2        2.416205
# 3        2.063487
# 4        1.726193
#            ...
# 64671    0.866912
# 64672    1.256046
# 64673    1.357978
# 64674    1.256046
# 64675    1.520340
# Name: w, Length: 64676, dtype: float64

# %% [markdown]
# # **MCLP 분석**

# %% [markdown]
# ## **MCLP 후보지 선정**

# %% [markdown]
# **최적화 문제 정의 및 해결**
#
# **수소충전소 위치 선정 최적화 모델 정의 및 결과**
#
# **최적화 모델 : Maximal Covering Location Problem (MCLP)**
#
# - 정의: MCLP는 최대지역커버문제로, 설비가 커버하는 수요 (covered demand)의 합을 최대화 하면서 주어진 K개의 설비를 세울 위치를 선정하는 문제
# - 가정
#
#     - 설비의 위치가 수요 발생 지점으로부터 일정 거리 Residual 이내에 수요를 커버함.
#     - 이때 거리 Residual은 커버리지 거리(covered distance) 라고 함.
#     - 커버되지 못한 수여는 서비스를 받지 못하는 수요가 아니라 서비스를 받긴 하지만 서비스 받는 설비로 부터의 거리가 커버리지 밖에 있어 만족할 만한 서비스 수준을 제공받지 못하는 수요를 의미
#
#
# - Mathematical statement
#
#
#     - i : 수요 포인트 index
#     - j : 설비 후보지역 index
#     - I : 수요 포인트 집합
#     - J : 설비 후보지역 집합
#     - K : 총 설치해야 하는 설비 개수
#     - x : 설비 후보 지역 중 위치 j에 설비가 설치되면 1, 그렇지 않으면 0
#     - y : 적어도 하나의 설비로 그 포인트가 커버가 되면 1, 그렇지 않으면 0
#
#
# - Formulation
#
# $$
# \begin{align*}
# &\text{maximize} \sum_{i\in I} w_i y_i ...(1) \\
# \text{s.t.} \quad & y_i \le \sum_{j\in N_i}x_j \qquad for \quad all \quad i\in I ... (2)\\
# &\sum_{j\in J}x_j = K ... (3)\\
# &x_j, y_i \in \{0,1\} \qquad for \quad all \quad i\in I,j\in J
# \end{align*}
# $$
#
#
#     -(1) : 목적함수, 가중치 w인 수요 포인트를 최대한 많이 커버하게 해라
#     -(2) : 수요포인트 i는 설비 후보 지역이 커버하는 거리안에서 적어도 하나 이상의 설비로 부터 커버가 된다.
#     -(3) : 총 설치할 설비는 K개 이다.

# %%
def generate_candidate_sites(points,M=100):
    '''
    Generate M candidate sites with the convex hull of a point set
    Input:
        points: a Numpy array with shape of (N,2)
        M: the number of candidate sites to generate
    Return:
        sites: a Numpy array with shape of (M,2)
    '''
    hull = ConvexHull(points)
    polygon_points = points[hull.vertices]
    poly = Polygon(polygon_points)
    min_x, min_y, max_x, max_y = poly.bounds
    sites = []
    while len(sites) < M:
        random_point = Point([random.uniform(min_x, max_x),
                             random.uniform(min_y, max_y)])
        if (random_point.within(poly)):
            sites.append(random_point)
    return np.array([(p.x,p.y) for p in sites])




def generate_candidate_sites(df_result_fin,M=100):
    from shapely.geometry import Polygon, Point
    sites = []
    idx=np.random.choice(np.array(range(0,len(df_result_fin))), M)
    for i in range(len(idx)):
        random_point = Point(np.array(df_result_fin.iloc[idx]['coord_cent'])[i][0],
                             np.array(df_result_fin.iloc[idx]['coord_cent'])[i][1])
        sites.append(random_point)
    return np.array([(p.x,p.y) for p in sites])

def generate_candidate_sites(df_result_fin,Weight,M=100):
    sites = []
    idx = df_result_fin.sort_values(by = Weight, ascending = False).iloc[1:M].index
    for i in range(len(idx)):
        random_point = Point(np.array(df_result_fin.loc[idx]['coord_cent'])[i][0],
                             np.array(df_result_fin.loc[idx]['coord_cent'])[i][1])
        sites.append(random_point)
    return np.array([(p.x,p.y) for p in sites])



from scipy.spatial import distance_matrix
def mclp(points,K,radius,M,df_result_fin,w,Weight):

    """
    Solve maximum covering location problem
    Input:
        points: input points, Numpy array in shape of [N,2]
        K: the number of sites to select
        radius: the radius of circle
        M: the number of candidate sites, which will randomly generated inside
        the ConvexHull wrapped by the polygon
    Return:
        opt_sites: locations K optimal sites, Numpy array in shape of [K,2]
        f: the optimal value of the objective function
    """
    print('----- Configurations -----')
    print('  Number of points %g' % points.shape[0])
    print('  K %g' % K)
    print('  Radius %g' % radius)
    print('  M %g' % M)
    import time
    start = time.time()
    sites = generate_candidate_sites(df_result_fin,Weight,M)
    J = sites.shape[0]
    I = points.shape[0]
    D = distance_matrix(points,sites)
    mask1 = D<=radius
    D[mask1]=1
    D[~mask1]=0

    from mip import Model, xsum, maximize, BINARY

    # Build model
    m = Model("mclp")
    # Add variables

    x = [m.add_var(name = "x%d" % j, var_type = BINARY) for j in range(J)]
    y = [m.add_var(name = "y%d" % i, var_type = BINARY) for i in range(I)]


    m.objective = maximize(xsum(w[i]*y[i] for i in range (I)))

    m += xsum(x[j] for j in range(J)) == K

    for i in range(I):
        m += xsum(x[j] for j in np.where(D[i]==1)[0]) >= y[i]

    m.optimize()
    
    end = time.time()
    print('----- Output -----')
    print('  Running time : %s seconds' % float(end-start))
    print('  Optimal coverage points: %g' % m.objective_value)

    solution = []
    for i in range(J):
        if x[i].x ==1:
            solution.append(int(x[i].name[1:]))
    opt_sites = sites[solution]
            
    return opt_sites,m.objective_value

# %%
# MCLP 분석 후보지
df_result_fin = df_total_con[(df_total_con['수소충전소']!=1) & (df_total_con['학교']!=1) & (df_total_con['유치원']!=1) & (df_total_con['LPG_충전소_nb']!=0)]
df_result_fin
# Out:
#             gid  ...         w
# 2169   다사624443  ...  2.290435
# 2717   다사651419  ...  0.713893
# 2948   다사627445  ...  2.290435
# 4899   다사672486  ...  2.419678
# 4947   다사671503  ...  1.226994
# ...         ...  ...       ...
# 62877  다사648557  ...  0.959105
# 62995  다사645572  ...  1.345241
# 63128  다사625550  ...  1.599792
# 64170  다사622575  ...  0.628646
# 64234  다사628534  ...  1.357978
#
# [75 rows x 21 columns]

# %%
import numpy as np

# %%
pip install mip
# Out:
# Collecting mip
#   Downloading mip-1.13.0-py3-none-any.whl (48.0 MB)
#      |████████████████████████████████| 48.0 MB 49 kB/s
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from mip) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->mip) (2.20)
# Installing collected packages: mip
# Successfully installed mip-1.13.0

# %% [markdown]
# ## **MCLP 분석**

# %%
## MCLP 분석
points = []
for i in df_result_fin['coord_cent'] :
    points.append(i)

w= []
for i in df_result_fin['w'] :
    w.append(i)

radius = (1/88.74/1000)*500   
K = 12
M = 75

opt_sites_org,f = mclp(np.array(points),K,radius,M,df_result_fin,w,'w')


df_opt_h2= pd.DataFrame(opt_sites_org)
df_opt_h2.columns = ['lon', 'lat']
df_opt_h2
# Out:
# ----- Configurations -----
#   Number of points 75
#   K 12
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 5.695087194442749 seconds
#   Optimal coverage points: 46.9024
#            lon        lat
# 0   127.103423  37.507660
# 1   127.066821  37.576034
# 2   127.129303  37.536588
# 3   126.860254  37.496678
# 4   127.075193  37.497647
# 5   126.906027  37.573532
# 6   126.877178  37.502177
# 7   126.902210  37.484279
# 8   127.058973  37.562485
# 9   126.860863  37.557973
# 10  126.816462  37.584765
# 11  127.073708  37.559835

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import folium

# %%
map=folium.Map(location=[df_opt_h2['lat'].mean(),df_opt_h2['lon'].mean()], zoom_start=11.5 )

for i in df_opt_h2.index:
  folium.Marker([ df_opt_h2.loc[i,'lat'], df_opt_h2.loc[i,'lon'] ], icon=folium.Icon(color='red')).add_to(map)    
  folium.CircleMarker( [ df_opt_h2.loc[i,'lat'], df_opt_h2.loc[i,'lon'] ], radius=10,color='red',fill_color='red').add_to(map)   

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1d1912a672ba4a0590f845e4f8a6935c%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1d1912a672ba4a0590f845e4f8a6935c%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1d1912a672ba4a0590f845e4f8a6935c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1d1912a672ba4a0590f845e4f8a6935c%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.53663781657928%2C%20126.97753447576275%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011.5%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_16b9ac22a16f441ea6d33500048b591f%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C ...

# %% [markdown]
# ## **후보지개수(K)에 따른 좌표 추출**

# %%
points = []
for i in df_result_fin['coord_cent'] :
    points.append(i)

w= []
for i in df_result_fin['w'] :
    w.append(i)

# %%
total = pd.DataFrame()

M = len(df_result_fin)

for i in range(1,M):
  radius = (1/88.74/1000)*500   
  K = i

  opt_sites_org,f = mclp(np.array(points),K,radius,M,df_result_fin,w,'w') 
  df_opt= pd.DataFrame(opt_sites_org)
  df_opt.insert(2, 'num', i, True)
  df_opt.columns = ['lon', 'lat','num']
  i = str(i)
  total = total.append(df_opt, ignore_index = True)
  total = total[['num', 'lon', 'lat']]
  
  print(total)
# Out:
# ----- Configurations -----
#   Number of points 75
#   K 1
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.743734359741211 seconds
#   Optimal coverage points: 6.44814
#    num         lon        lat
# 0    1  127.058973  37.562485
# ----- Configurations -----
#   Number of points 75
#   K 2
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.7315020561218262 seconds
#   Optimal coverage points: 12.7527
#    num         lon        lat
# 0    1  127.058973  37.562485
# 1    2  127.058973  37.562485
# 2    2  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 3
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.767888069152832 seconds
#   Optimal coverage points: 17.3336
#    num         lon        lat
# 0    1  127.058973  37.562485
# 1    2  127.058973  37.562485
# 2    2  126.860863  37.557973
# 3    3  127.075193  37.497647
# 4    3  127.058973  37.562485
# 5    3  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 4
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.769455909729004 seconds
#   Optimal coverage points: 21.9125
#    num         lon        lat
# 0    1  127.058973  37.562485
# 1    2  127.058973  37.562485
# 2    2  126.860863  37.557973
# 3    3  127.075193  37.497647
# 4    3  127.058973  37.562485
# 5    3  126.860863  37.557973
# 6    4  127.075193  37.497647
# 7    4  126.906027  37.573532
# 8    4  127.058973  37.562485
# 9    4  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 5
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6855051517486572 seconds
#   Optimal coverage points: 26.3544
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 6
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6411690711975098 seconds
#   Optimal coverage points: 30.77
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# 15    6  127.075193  37.497647
# 16    6  126.906027  37.573532
# 17    6  126.877178  37.502177
# 18    6  126.902210  37.484279
# 19    6  127.058973  37.562485
# 20    6  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 7
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.7113032341003418 seconds
#   Optimal coverage points: 34.8162
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# 15    6  127.075193  37.497647
# 16    6  126.906027  37.573532
# 17    6  126.877178  37.502177
# 18    6  126.902210  37.484279
# 19    6  127.058973  37.562485
# 20    6  126.860863  37.557973
# 21    7  127.103423  37.507660
# 22    7  127.075193  37.497647
# 23    7  126.906027  37.573532
# 24    7  126.877178  37.502177
# 25    7  126.902210  37.484279
# 26    7  127.058973  37.562485
# 27    7  126.860863  37.557973
# ----- Configurations -----
#   Number of points 75
#   K 8
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6693837642669678 seconds
#   Optimal coverage points: 37.3239
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# 15    6  127.075193  37.497647
# 16    6  126.906027  37.573532
# 17    6  126.877178  37.502177
# 18    6  126.902210  37.484279
# 19    6  127.058973  37.562485
# 20    6  126.860863  37.557973
# 21    7  127.103423  37.507660
# 22    7  127.075193  37.497647
# 23    7  126.906027  37.573532
# 24    7  126.877178  37.502177
# 25    7  126.902210  37.484279
# 26    7  127.058973  37.562485
# 27    7  126.860863  37.557973
# 28    8  127.103423  37.507660
# 29    8  127.075193  37.497647
# 30    8  126.906027  37.573532
# 31    8  126.877178  37.502177
# 32    8  126.902210  37.484279
# 33    8  127.058973  37.562485
# 34    8  126.860863  37.557973
# 35    8  126.816462  37.584765
# ----- Configurations -----
#   Number of points 75
#   K 9
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5778491497039795 seconds
#   Optimal coverage points: 39.8193
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# 15    6  127.075193  37.497647
# 16    6  126.906027  37.573532
# 17    6  126.877178  37.502177
# 18    6  126.902210  37.484279
# 19    6  127.058973  37.562485
# 20    6  126.860863  37.557973
# 21    7  127.103423  37.507660
# 22    7  127.075193  37.497647
# 23    7  126.906027  37.573532
# 24    7  126.877178  37.502177
# 25    7  126.902210  37.484279
# 26    7  127.058973  37.562485
# 27    7  126.860863  37.557973
# 28    8  127.103423  37.507660
# 29    8  127.075193  37.497647
# 30    8  126.906027  37.573532
# 31    8  126.877178  37.502177
# 32    8  126.902210  37.484279
# 33    8  127.058973  37.562485
# 34    8  126.860863  37.557973
# 35    8  126.816462  37.584765
# 36    9  127.103423  37.507660
# 37    9  127.066821  37.576034
# 38    9  127.075193  37.497647
# 39    9  126.906027  37.573532
# 40    9  126.877178  37.502177
# 41    9  126.902210  37.484279
# 42    9  127.058973  37.562485
# 43    9  126.860863  37.557973
# 44    9  126.816462  37.584765
# ----- Configurations -----
#   Number of points 75
#   K 10
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.635500192642212 seconds
#   Optimal coverage points: 42.2389
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# 5     3  126.860863  37.557973
# 6     4  127.075193  37.497647
# 7     4  126.906027  37.573532
# 8     4  127.058973  37.562485
# 9     4  126.860863  37.557973
# 10    5  127.075193  37.497647
# 11    5  126.906027  37.573532
# 12    5  126.877178  37.502177
# 13    5  127.058973  37.562485
# 14    5  126.860863  37.557973
# 15    6  127.075193  37.497647
# 16    6  126.906027  37.573532
# 17    6  126.877178  37.502177
# 18    6  126.902210  37.484279
# 19    6  127.058973  37.562485
# 20    6  126.860863  37.557973
# 21    7  127.103423  37.507660
# 22    7  127.075193  37.497647
# 23    7  126.906027  37.573532
# 24    7  126.877178  37.502177
# 25    7  126.902210  37.484279
# 26    7  127.058973  37.562485
# 27    7  126.860863  37.557973
# 28    8  127.103423  37.507660
# 29    8  127.075193  37.497647
# 30    8  126.906027  37.573532
# 31    8  126.877178  37.502177
# 32    8  126.902210  37.484279
# 33    8  127.058973  37.562485
# 34    8  126.860863  37.557973
# 35    8  126.816462  37.584765
# 36    9  127.103423  37.507660
# 37    9  127.066821  37.576034
# 38    9  127.075193  37.497647
# 39    9  126.906027  37.573532
# 40    9  126.877178  37.502177
# 41    9  126.902210  37.484279
# 42    9  127.058973  37.562485
# 43    9  126.860863  37.557973
# 44    9  126.816462  37.584765
# 45   10  127.103423  37.507660
# 46   10  127.066821  37.576034
# 47   10  127.129303  37.536588
# 48   10  127.075193  37.497647
# 49   10  126.906027  37.573532
# 50   10  126.877178  37.502177
# 51   10  126.902210  37.484279
# 52   10  127.058973  37.562485
# 53   10  126.860863  37.557973
# 54   10  126.816462  37.584765
# ----- Configurations -----
#   Number of points 75
#   K 11
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.683004379272461 seconds
#   Optimal coverage points: 44.6159
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# ..  ...         ...        ...
# 61   11  126.877178  37.502177
# 62   11  126.902210  37.484279
# 63   11  127.058973  37.562485
# 64   11  126.860863  37.557973
# 65   11  126.816462  37.584765
#
# [66 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 12
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.632688045501709 seconds
#   Optimal coverage points: 46.9024
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# ..  ...         ...        ...
# 73   12  126.902210  37.484279
# 74   12  127.058973  37.562485
# 75   12  126.860863  37.557973
# 76   12  126.816462  37.584765
# 77   12  127.073708  37.559835
#
# [78 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 13
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5278072357177734 seconds
#   Optimal coverage points: 49.0969
#     num         lon        lat
# 0     1  127.058973  37.562485
# 1     2  127.058973  37.562485
# 2     2  126.860863  37.557973
# 3     3  127.075193  37.497647
# 4     3  127.058973  37.562485
# ..  ...         ...        ...
# 86   13  126.847520  37.529959
# 87   13  127.058973  37.562485
# 88   13  126.860863  37.557973
# 89   13  126.816462  37.584765
# 90   13  127.073708  37.559835
#
# [91 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 14
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6312997341156006 seconds
#   Optimal coverage points: 51.2906
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 100   14  127.016905  37.589361
# 101   14  127.058973  37.562485
# 102   14  126.860863  37.557973
# 103   14  126.816462  37.584765
# 104   14  127.073708  37.559835
#
# [105 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 15
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.515486240386963 seconds
#   Optimal coverage points: 53.4329
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 115   15  127.058973  37.562485
# 116   15  126.827068  37.538857
# 117   15  126.860863  37.557973
# 118   15  126.816462  37.584765
# 119   15  127.073708  37.559835
#
# [120 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 16
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6377360820770264 seconds
#   Optimal coverage points: 55.4395
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 131   16  126.827068  37.538857
# 132   16  126.860863  37.557973
# 133   16  126.831668  37.530771
# 134   16  126.816462  37.584765
# 135   16  127.073708  37.559835
#
# [136 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 17
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.630521535873413 seconds
#   Optimal coverage points: 57.4259
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 148   17  126.860863  37.557973
# 149   17  126.831668  37.530771
# 150   17  126.837415  37.520889
# 151   17  126.816462  37.584765
# 152   17  127.073708  37.559835
#
# [153 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 18
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5489723682403564 seconds
#   Optimal coverage points: 59.3558
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 166   18  126.831668  37.530771
# 167   18  126.837415  37.520889
# 168   18  127.131717  37.505949
# 169   18  126.816462  37.584765
# 170   18  127.073708  37.559835
#
# [171 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 19
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5662858486175537 seconds
#   Optimal coverage points: 61.1745
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 185   19  126.837415  37.520889
# 186   19  127.131717  37.505949
# 187   19  127.032418  37.644405
# 188   19  126.816462  37.584765
# 189   19  127.073708  37.559835
#
# [190 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 20
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5431039333343506 seconds
#   Optimal coverage points: 62.9129
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 205   20  127.131717  37.505949
# 206   20  127.032418  37.644405
# 207   20  126.897867  37.461723
# 208   20  126.816462  37.584765
# 209   20  127.073708  37.559835
#
# [210 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 21
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5392951965332031 seconds
#   Optimal coverage points: 64.5393
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 226   21  127.032418  37.644405
# 227   21  126.897867  37.461723
# 228   21  127.060941  37.612968
# 229   21  126.816462  37.584765
# 230   21  127.073708  37.559835
#
# [231 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 22
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5730040073394775 seconds
#   Optimal coverage points: 66.1502
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 248   22  126.897867  37.461723
# 249   22  127.060941  37.612968
# 250   22  127.041386  37.660664
# 251   22  126.816462  37.584765
# 252   22  127.073708  37.559835
#
# [253 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 23
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5909833908081055 seconds
#   Optimal coverage points: 67.75
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 271   23  127.060941  37.612968
# 272   23  127.041386  37.660664
# 273   23  127.075778  37.594094
# 274   23  126.816462  37.584765
# 275   23  127.073708  37.559835
#
# [276 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 24
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.7231674194335938 seconds
#   Optimal coverage points: 69.2715
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 295   24  127.041386  37.660664
# 296   24  127.075778  37.594094
# 297   24  126.929239  37.499736
# 298   24  126.816462  37.584765
# 299   24  127.073708  37.559835
#
# [300 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 25
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6490159034729004 seconds
#   Optimal coverage points: 70.7779
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 320   25  127.075778  37.594094
# 321   25  126.929239  37.499736
# 322   25  127.084038  37.534634
# 323   25  126.816462  37.584765
# 324   25  127.073708  37.559835
#
# [325 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 26
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5972163677215576 seconds
#   Optimal coverage points: 72.2691
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 346   26  126.929239  37.499736
# 347   26  127.084038  37.534634
# 348   26  126.837661  37.492949
# 349   26  126.816462  37.584765
# 350   26  127.073708  37.559835
#
# [351 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 27
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5336978435516357 seconds
#   Optimal coverage points: 73.7323
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 373   27  127.084038  37.534634
# 374   27  126.837661  37.492949
# 375   27  126.953187  37.473710
# 376   27  126.816462  37.584765
# 377   27  127.073708  37.559835
#
# [378 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 28
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5752754211425781 seconds
#   Optimal coverage points: 75.1915
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 401   28  126.837661  37.492949
# 402   28  126.953187  37.473710
# 403   28  127.052250  37.550742
# 404   28  126.816462  37.584765
# 405   28  127.073708  37.559835
#
# [406 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 29
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.4911715984344482 seconds
#   Optimal coverage points: 76.5568
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 430   29  126.953187  37.473710
# 431   29  127.052250  37.550742
# 432   29  127.059946  37.589529
# 433   29  126.816462  37.584765
# 434   29  127.073708  37.559835
#
# [435 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 30
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5815753936767578 seconds
#   Optimal coverage points: 77.9147
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 460   30  127.052250  37.550742
# 461   30  127.059946  37.589529
# 462   30  127.079257  37.579685
# 463   30  126.816462  37.584765
# 464   30  127.073708  37.559835
#
# [465 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 31
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5069804191589355 seconds
#   Optimal coverage points: 79.26
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 491   31  127.059946  37.589529
# 492   31  127.079257  37.579685
# 493   31  127.098326  37.614002
# 494   31  126.816462  37.584765
# 495   31  127.073708  37.559835
#
# [496 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 32
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5397543907165527 seconds
#   Optimal coverage points: 80.5923
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 523   32  127.079257  37.579685
# 524   32  127.098326  37.614002
# 525   32  127.067530  37.649046
# 526   32  126.816462  37.584765
# 527   32  127.073708  37.559835
#
# [528 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 33
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5535380840301514 seconds
#   Optimal coverage points: 81.9162
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 556   33  127.098326  37.614002
# 557   33  127.067530  37.649046
# 558   33  127.011701  37.519034
# 559   33  126.816462  37.584765
# 560   33  127.073708  37.559835
#
# [561 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 34
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.7544312477111816 seconds
#   Optimal coverage points: 83.2091
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 590   34  127.067530  37.649046
# 591   34  127.011701  37.519034
# 592   34  126.982553  37.479250
# 593   34  126.816462  37.584765
# 594   34  127.073708  37.559835
#
# [595 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 35
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.6164186000823975 seconds
#   Optimal coverage points: 84.4923
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 625   35  127.011701  37.519034
# 626   35  126.982553  37.479250
# 627   35  126.995036  37.472995
# 628   35  126.816462  37.584765
# 629   35  127.073708  37.559835
#
# [630 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 36
#   Radius 0.00563444
#   M 75
# ----- Output -----
#   Running time : 1.5440585613250732 seconds
#   Optimal coverage points: 85.7671
#      num         lon        lat
# 0      1  127.058973  37.562485
# 1      2  127.058973  37.562485
# 2      2  126.860863  37.557973
# 3      3  127.075193  37.497647
# 4      3  127.058973  37.562485
# ..   ...         ...        ...
# 661   36  126.982553  37.479250
# 662   36  126.995036  37.472995
# 663   36  127.027935  37.636275
# 664   36  126.816462  37.584765
# 665   36  127.073708  37.559835
#
# [666 rows x 3 columns]
# ----- Configurations -----
#   Number of points 75
#   K 37
#   Radius 0.00563444
#   M 75

# %%
total.to_csv('total_coor_75_2km커버리지.csv', encoding='euc-kr')
